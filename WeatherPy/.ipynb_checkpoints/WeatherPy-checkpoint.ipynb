# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 630

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

#Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

#set up lists to hold weather response info
city_name = []
lat = []
long = []
maxtemp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

#Being print statement
print ("Beginning Data Retrieval")
print ("-------------------------")

#Loop through list of cities and perform request for weather data on each
for city in cities:
    response = requests.get(query_url + city).json()
    try:
        lat.append(response['coord']['lat'])
        long.append(response['coord']['lon'])
        maxtemp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        city_number = len(cloudiness)
        print (f'Processing Record {city_number}:{city}')
        city_name.append(response['name'])
    
    #If city search cannot retrieve temperature data, print statement
    except:
        print ("City not found...skipping")

#End print statement
print ("-------------------------")
print ("Data Retrieval Complete")
print ("-------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1:cabo san lucas
# City not found...skipping
# Processing Record 2:mahebourg
# Processing Record 3:punta arenas
# Processing Record 4:airai
# Processing Record 5:mar del plata
# Processing Record 6:hobart
# Processing Record 7:tomaszow mazowiecki
# Processing Record 8:lahad datu
# Processing Record 9:khatanga
# Processing Record 10:yar-sale
# Processing Record 11:rikitea
# City not found...skipping
# Processing Record 12:mataura
# Processing Record 13:mount gambier
# Processing Record 14:busselton
# Processing Record 15:faya
# Processing Record 16:khani
# Processing Record 17:kruisfontein
# Processing Record 18:namatanai
# Processing Record 19:carquefou
# Processing Record 20:ondjiva
# Processing Record 21:broome
# Processing Record 22:sakaiminato
# Processing Record 23:yining
# Processing Record 24:cabanas
# Processing Record 25:georgetown
# Processing Record 26:hermanus
# Processing Record 27:dingle
# Processing Record 28:port elizabeth
# Processing Record 29:avera
# Processing Record 30:yellowknife
# Processing Record 31:kudahuvadhoo
# Processing Record 32:collipulli
# Processing Record 33:laguna
# Processing Record 34:victoria
# Processing Record 35:iqaluit
# Processing Record 36:bluff
# Processing Record 37:ishinomaki
# Processing Record 38:atuona
# Processing Record 39:seoni malwa
# City not found...skipping
# Processing Record 40:new norfolk
# Processing Record 41:high level
# Processing Record 42:esperance
# Processing Record 43:dalaba
# Processing Record 44:kaitangata
# Processing Record 45:port alfred
# Processing Record 46:belmonte
# Processing Record 47:ushuaia
# Processing Record 48:barabai
# Processing Record 49:norman wells
# Processing Record 50:faanui
# Processing Record 51:cuauhtemoc
# Processing Record 52:kahului
# Processing Record 53:sao gabriel da cachoeira
# Processing Record 54:tucumcari
# Processing Record 55:coihaique
# Processing Record 56:puerto ayora
# Processing Record 57:champerico
# Processing Record 58:kirakira
# Processing Record 59:barrow
# Processing Record 60:juruti
# Processing Record 61:castro
# Processing Record 62:shiloh
# Processing Record 63:ponta do sol
# Processing Record 64:qaanaaq
# Processing Record 65:albany
# Processing Record 66:kununurra
# Processing Record 67:karratha
# Processing Record 68:lock haven
# Processing Record 69:kibala
# City not found...skipping
# City not found...skipping
# Processing Record 70:udachnyy
# Processing Record 71:vila velha
# Processing Record 72:barsovo
# Processing Record 73:zadar
# Processing Record 74:lakes entrance
# Processing Record 75:cape town
# Processing Record 76:tuktoyaktuk
# City not found...skipping
# Processing Record 77:bethel
# Processing Record 78:vaini
# Processing Record 79:south yarmouth
# Processing Record 80:praia da vitoria
# Processing Record 81:kyzyl-suu
# Processing Record 82:jamestown
# Processing Record 83:sao filipe
# Processing Record 84:beringovskiy
# Processing Record 85:siemiatycze
# Processing Record 86:lagoa
# Processing Record 87:geraldton
# City not found...skipping
# Processing Record 88:adrar
# Processing Record 89:kapaa
# Processing Record 90:cortes
# Processing Record 91:marsh harbour
# Processing Record 92:ler
# Processing Record 93:bayir
# City not found...skipping
# Processing Record 94:chuy
# Processing Record 95:krasnoselkup
# Processing Record 96:tamiahua
# Processing Record 97:obregon
# Processing Record 98:arraial do cabo
# City not found...skipping
# Processing Record 99:chunoyar
# Processing Record 100:calama
# Processing Record 101:zhangye
# Processing Record 102:kankaanpaa
# Processing Record 103:kavieng
# Processing Record 104:tura
# Processing Record 105:mpraeso
# Processing Record 106:langnau
# Processing Record 107:severo-kurilsk
# Processing Record 108:storforshei
# Processing Record 109:griffith
# Processing Record 110:saskylakh
# Processing Record 111:atasu
# Processing Record 112:tulun
# Processing Record 113:santa helena de goias
# Processing Record 114:gat
# Processing Record 115:husavik
# City not found...skipping
# Processing Record 116:kirensk
# Processing Record 117:pisco
# Processing Record 118:korla
# Processing Record 119:qena
# Processing Record 120:tasiilaq
# Processing Record 121:kargasok
# Processing Record 122:bredasdorp
# Processing Record 123:esil
# Processing Record 124:cockburn town
# Processing Record 125:karasjok
# Processing Record 126:nemuro
# Processing Record 127:eha amufu
# Processing Record 128:halifax
# City not found...skipping
# Processing Record 129:dryden
# Processing Record 130:cacador
# Processing Record 131:vao
# Processing Record 132:mehamn
# Processing Record 133:lebu
# Processing Record 134:longyearbyen
# Processing Record 135:vila franca do campo
# Processing Record 136:auray
# Processing Record 137:denpasar
# Processing Record 138:dikson
# Processing Record 139:tuatapere
# Processing Record 140:hamilton
# Processing Record 141:swidnik
# Processing Record 142:labuhan
# Processing Record 143:asarganj
# Processing Record 144:komsomolskiy
# Processing Record 145:novikovo
# Processing Record 146:tortoli
# Processing Record 147:monrovia
# Processing Record 148:cherskiy
# Processing Record 149:sitka
# Processing Record 150:srednekolymsk
# Processing Record 151:saint george
# Processing Record 152:upernavik
# Processing Record 153:seoul
# Processing Record 154:east london
# Processing Record 155:kavaratti
# Processing Record 156:abu samrah
# Processing Record 157:inhambane
# Processing Record 158:coquimbo
# Processing Record 159:djougou
# Processing Record 160:palauig
# Processing Record 161:leningradskiy
# Processing Record 162:tahlequah
# Processing Record 163:lucapa
# Processing Record 164:linhares
# Processing Record 165:ahipara
# Processing Record 166:anadyr
# Processing Record 167:kampene
# Processing Record 168:fortuna
# Processing Record 169:alvorada
# Processing Record 170:sao joao da barra
# Processing Record 171:eureka
# City not found...skipping
# Processing Record 172:roald
# Processing Record 173:bull savanna
# Processing Record 174:mulchen
# Processing Record 175:prince albert
# City not found...skipping
# Processing Record 176:pachora
# Processing Record 177:lorengau
# City not found...skipping
# Processing Record 178:kuzino
# Processing Record 179:formosa
# Processing Record 180:yuzhno-kurilsk
# Processing Record 181:ossora
# Processing Record 182:kokopo
# Processing Record 183:avarua
# Processing Record 184:verin
# City not found...skipping
# Processing Record 185:butaritari
# Processing Record 186:maragogi
# Processing Record 187:bentiu
# Processing Record 188:caibarien
# Processing Record 189:george
# Processing Record 190:alofi
# Processing Record 191:gamboula
# Processing Record 192:belaya gora
# City not found...skipping
# Processing Record 193:port-gentil
# Processing Record 194:thompson
# Processing Record 195:hilo
# Processing Record 196:koscierzyna
# Processing Record 197:havre-saint-pierre
# Processing Record 198:carnarvon
# Processing Record 199:la rioja
# Processing Record 200:te anau
# Processing Record 201:sur
# Processing Record 202:alekseyevsk
# Processing Record 203:muisne
# City not found...skipping
# Processing Record 204:jumla
# Processing Record 205:bom despacho
# Processing Record 206:mariental
# Processing Record 207:boa vista
# Processing Record 208:arroyo
# Processing Record 209:bengkulu
# Processing Record 210:terney
# Processing Record 211:aguimes
# Processing Record 212:qaqortoq
# Processing Record 213:katsuura
# Processing Record 214:nikitinskiy
# Processing Record 215:bom jesus
# Processing Record 216:presidencia roque saenz pena
# Processing Record 217:grand forks
# Processing Record 218:pakxe
# Processing Record 219:midlothian
# Processing Record 220:padang
# Processing Record 221:paamiut
# Processing Record 222:mirwah
# Processing Record 223:hithadhoo
# Processing Record 224:chengde
# Processing Record 225:puntarenas
# Processing Record 226:tiksi
# Processing Record 227:namibe
# Processing Record 228:soyo
# Processing Record 229:loandjili
# Processing Record 230:arteaga
# Processing Record 231:farafangana
# City not found...skipping
# Processing Record 232:marinette
# Processing Record 233:chokurdakh
# Processing Record 234:baiquan
# Processing Record 235:bada
# City not found...skipping
# Processing Record 236:porto murtinho
# Processing Record 237:tautira
# Processing Record 238:clyde river
# Processing Record 239:taiobeiras
# Processing Record 240:maymyo
# Processing Record 241:luderitz
# Processing Record 242:talnakh
# Processing Record 243:sajkas
# Processing Record 244:narsaq
# Processing Record 245:pokrovsk
# Processing Record 246:vung tau
# Processing Record 247:semirom
# Processing Record 248:derzhavinsk
# Processing Record 249:verkhoyansk
# Processing Record 250:sri aman
# Processing Record 251:kodiak
# Processing Record 252:taoudenni
# Processing Record 253:pavilosta
# Processing Record 254:san quintin
# Processing Record 255:kenitra
# Processing Record 256:fukue
# Processing Record 257:caravelas
# City not found...skipping
# Processing Record 258:nome
# Processing Record 259:pasighat
# Processing Record 260:ocean city
# Processing Record 261:nhulunbuy
# Processing Record 262:greensburg
# Processing Record 263:ancud
# Processing Record 264:teguise
# Processing Record 265:luganville
# Processing Record 266:la ronge
# Processing Record 267:huarmey
# Processing Record 268:chutove
# Processing Record 269:constitucion
# Processing Record 270:port blair
# City not found...skipping
# Processing Record 271:vestmanna
# Processing Record 272:sturgis
# Processing Record 273:broken hill
# Processing Record 274:tulum
# Processing Record 275:saint-francois
# Processing Record 276:nikolskoye
# Processing Record 277:tynda
# Processing Record 278:mezhdurechensk
# Processing Record 279:platonovka
# Processing Record 280:raudeberg
# Processing Record 281:mountain home
# Processing Record 282:miandrivazo
# Processing Record 283:mae sai
# Processing Record 284:torbay
# Processing Record 285:saint-philippe
# Processing Record 286:pangkalanbuun
# Processing Record 287:san cristobal
# Processing Record 288:medias
# Processing Record 289:gidole
# Processing Record 290:san patricio
# Processing Record 291:almaznyy
# Processing Record 292:high rock
# Processing Record 293:bud
# Processing Record 294:vardo
# Processing Record 295:vakhrushi
# Processing Record 296:sorland
# Processing Record 297:saldanha
# Processing Record 298:deputatskiy
# Processing Record 299:sioux lookout
# Processing Record 300:opuwo
# Processing Record 301:kalabo
# Processing Record 302:andenes
# Processing Record 303:mildura
# Processing Record 304:along
# Processing Record 305:abu zabad
# City not found...skipping
# Processing Record 306:vostok
# Processing Record 307:yablonovo
# Processing Record 308:buala
# Processing Record 309:hami
# Processing Record 310:hualmay
# Processing Record 311:yumen
# City not found...skipping
# Processing Record 312:eyl
# Processing Record 313:souillac
# Processing Record 314:ostrovnoy
# Processing Record 315:itaituba
# Processing Record 316:doba
# Processing Record 317:mangrol
# Processing Record 318:noumea
# City not found...skipping
# Processing Record 319:batagay
# Processing Record 320:suntar
# Processing Record 321:stokmarknes
# Processing Record 322:sheksna
# City not found...skipping
# Processing Record 323:tottori
# Processing Record 324:havoysund
# Processing Record 325:lompoc
# Processing Record 326:urumqi
# Processing Record 327:san rafael del sur
# City not found...skipping
# Processing Record 328:mandalgovi
# Processing Record 329:penalva
# Processing Record 330:pevek
# Processing Record 331:hauzenberg
# Processing Record 332:inuvik
# Processing Record 333:cidreira
# Processing Record 334:henties bay
# Processing Record 335:pontal
# Processing Record 336:taltal
# City not found...skipping
# Processing Record 337:bakau
# Processing Record 338:axim
# Processing Record 339:zlobin
# Processing Record 340:sao raimundo nonato
# Processing Record 341:palmer
# Processing Record 342:kuytun
# Processing Record 343:santa maria
# Processing Record 344:prince rupert
# Processing Record 345:isangel
# Processing Record 346:klaksvik
# Processing Record 347:asau
# Processing Record 348:caohai
# Processing Record 349:kanganpur
# Processing Record 350:charlestown
# Processing Record 351:flinders
# Processing Record 352:dwarka
# City not found...skipping
# City not found...skipping
# City not found...skipping
# Processing Record 353:orshanka
# Processing Record 354:kushima
# City not found...skipping
# Processing Record 355:makrana
# Processing Record 356:svetlyy
# Processing Record 357:bafia
# Processing Record 358:kamenka
# Processing Record 359:makakilo city
# Processing Record 360:ramos arizpe
# Processing Record 361:san pedro
# Processing Record 362:darhan
# Processing Record 363:izumrud
# Processing Record 364:sao pedro da aldeia
# Processing Record 365:pasni
# Processing Record 366:bambous virieux
# Processing Record 367:mayumba
# Processing Record 368:guerrero negro
# Processing Record 369:vilyuysk
# Processing Record 370:vila
# Processing Record 371:omsukchan
# City not found...skipping
# Processing Record 372:shenjiamen
# City not found...skipping
# Processing Record 373:siwana
# Processing Record 374:gondanglegi
# City not found...skipping
# Processing Record 375:hasaki
# Processing Record 376:chicama
# Processing Record 377:acarau
# Processing Record 378:haapiti
# Processing Record 379:malaya serdoba
# Processing Record 380:clinton
# Processing Record 381:nikolayevsk-na-amure
# Processing Record 382:portland
# Processing Record 383:port hedland
# Processing Record 384:kieta
# Processing Record 385:corner brook
# Processing Record 386:davila
# Processing Record 387:cassia
# City not found...skipping
# Processing Record 388:nkongsamba
# Processing Record 389:neiafu
# Processing Record 390:comodoro rivadavia
# Processing Record 391:loikaw
# Processing Record 392:xining
# Processing Record 393:sinnamary
# Processing Record 394:mae hong son
# Processing Record 395:provideniya
# Processing Record 396:dunedin
# Processing Record 397:goderich
# Processing Record 398:vestmannaeyjar
# Processing Record 399:olutanga
# Processing Record 400:koumac
# Processing Record 401:hearst
# Processing Record 402:niamey
# Processing Record 403:sitio novo do tocantins
# Processing Record 404:quatre cocos
# Processing Record 405:xingyi
# Processing Record 406:pringsewu
# Processing Record 407:sungai besar
# Processing Record 408:murgab
# Processing Record 409:sesheke
# Processing Record 410:parlakimidi
# Processing Record 411:poya
# Processing Record 412:omboue
# Processing Record 413:la foa
# Processing Record 414:weinan
# Processing Record 415:ribeira grande
# Processing Record 416:marsa matruh
# Processing Record 417:traverse city
# Processing Record 418:kearney
# Processing Record 419:belyy yar
# Processing Record 420:los llanos de aridane
# Processing Record 421:baykit
# City not found...skipping
# Processing Record 422:fairmont
# City not found...skipping
# Processing Record 423:dhidhdhoo
# Processing Record 424:kikwit
# Processing Record 425:binzhou
# Processing Record 426:balabac
# Processing Record 427:cherlak
# Processing Record 428:mount isa
# Processing Record 429:magomeni
# Processing Record 430:punto fijo
# Processing Record 431:ust-omchug
# Processing Record 432:bathsheba
# Processing Record 433:ahtopol
# Processing Record 434:yakeshi
# Processing Record 435:selfoss
# Processing Record 436:balkhash
# City not found...skipping
# Processing Record 437:sarangani
# Processing Record 438:hodkovice nad mohelkou
# Processing Record 439:watertown
# Processing Record 440:lavrentiya
# Processing Record 441:osorno
# Processing Record 442:vicuna
# Processing Record 443:yerbogachen
# Processing Record 444:benjamin hill
# Processing Record 445:praya
# City not found...skipping
# Processing Record 446:baglan
# Processing Record 447:atar
# Processing Record 448:whitehorse
# Processing Record 449:gazimurskiy zavod
# City not found...skipping
# Processing Record 450:codrington
# Processing Record 451:dakar
# City not found...skipping
# Processing Record 452:inirida
# Processing Record 453:kapoeta
# Processing Record 454:ugoofaaru
# Processing Record 455:cayenne
# Processing Record 456:aklavik
# Processing Record 457:chateau-gontier
# Processing Record 458:menzelinsk
# Processing Record 459:mananara
# Processing Record 460:nanortalik
# Processing Record 461:verkh-usugli
# Processing Record 462:moose factory
# Processing Record 463:zharkent
# Processing Record 464:cape canaveral
# Processing Record 465:manta
# City not found...skipping
# Processing Record 466:vilhena
# Processing Record 467:ambilobe
# Processing Record 468:tabuk
# Processing Record 469:nuuk
# Processing Record 470:hobyo
# Processing Record 471:ous
# Processing Record 472:dudinka
# Processing Record 473:wladyslawowo
# Processing Record 474:bonthe
# Processing Record 475:kaeo
# Processing Record 476:hit
# Processing Record 477:batemans bay
# Processing Record 478:lakatoro
# Processing Record 479:karakol
# City not found...skipping
# Processing Record 480:kinablangan
# Processing Record 481:langarud
# Processing Record 482:yulara
# Processing Record 483:port hardy
# Processing Record 484:zhucheng
# Processing Record 485:lasa
# Processing Record 486:muravlenko
# Processing Record 487:humboldt
# Processing Record 488:buraydah
# City not found...skipping
# Processing Record 489:ca mau
# Processing Record 490:mecca
# Processing Record 491:manaure
# Processing Record 492:gizo
# Processing Record 493:tokur
# Processing Record 494:yarqa
# Processing Record 495:ola
# Processing Record 496:salalah
# Processing Record 497:salinopolis
# Processing Record 498:marzuq
# Processing Record 499:dongsheng
# Processing Record 500:bodrum
# Processing Record 501:nyurba
# Processing Record 502:brigantine
# Processing Record 503:katangli
# Processing Record 504:natal
# Processing Record 505:cuenca
# Processing Record 506:nanakuli
# Processing Record 507:santo tomas
# Processing Record 508:thunder bay
# City not found...skipping
# Processing Record 509:yaring
# Processing Record 510:dalby
# Processing Record 511:codajas
# Processing Record 512:cururupu
# Processing Record 513:miyako
# Processing Record 514:muhos
# Processing Record 515:tolaga bay
# City not found...skipping
# Processing Record 516:atherton
# Processing Record 517:richards bay
# Processing Record 518:provo
# Processing Record 519:matara
# Processing Record 520:zhangjiakou
# Processing Record 521:yinchuan
# Processing Record 522:san jose
# City not found...skipping
# Processing Record 523:kenai
# Processing Record 524:keuruu
# Processing Record 525:dinar
# Processing Record 526:fort nelson
# Processing Record 527:camapua
# City not found...skipping
# Processing Record 528:shumskiy
# Processing Record 529:lata
# Processing Record 530:freeport
# City not found...skipping
# Processing Record 531:russell
# Processing Record 532:melo
# Processing Record 533:churapcha
# Processing Record 534:coos bay
# Processing Record 535:college
# Processing Record 536:matagami
# Processing Record 537:alegrete
# Processing Record 538:maloy
# Processing Record 539:the pas
# Processing Record 540:bonavista
# Processing Record 541:new ulm
# Processing Record 542:tomatlan
# Processing Record 543:queanbeyan
# Processing Record 544:beckley
# Processing Record 545:mnogovershinnyy
# Processing Record 546:kabo
# Processing Record 547:tual
# Processing Record 548:eenhana
# Processing Record 549:tazovskiy
# Processing Record 550:chardara
# Processing Record 551:banda aceh
# Processing Record 552:tenenkou
# Processing Record 553:grand haven
# Processing Record 554:dorado
# Processing Record 555:bowling green
# Processing Record 556:tianpeng
# City not found...skipping
# Processing Record 557:staraya poltavka
# Processing Record 558:basar
# Processing Record 559:diveyevo
# Processing Record 560:fort saint james
# Processing Record 561:aljezur
# Processing Record 562:rosendal
# Processing Record 563:jawhar
# City not found...skipping
# Processing Record 564:ust-tsilma
# Processing Record 565:ilulissat
# Processing Record 566:manokwari
# Processing Record 567:yarada
# Processing Record 568:penzance
# Processing Record 569:edendale
# Processing Record 570:mokhsogollokh
# Processing Record 571:bulungu
# Processing Record 572:ixtapa
# Processing Record 573:fatehabad
# Processing Record 574:lumeje
# Processing Record 575:saiha
# Processing Record 576:poum
# Processing Record 577:griesheim
# Processing Record 578:rincon
# Processing Record 579:haines junction
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data = pd.DataFrame({"City": city_name, "Lat": lat, "Long": long,
                             "Max Temp": maxtemp, "Humidity": humidity, "Cloudiness": cloudiness,
                             "Wind Speed": wind_speed, "Country": country, "Date": date})

# %%
city_data.describe()
# Out:
#               Lat        Long    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  579.000000  579.000000  579.000000  579.000000  579.000000  579.000000
# mean    22.058307   18.878515   67.608998   69.680484   49.024180    7.930535
# std     32.985539   91.311514   14.084039   21.335266   37.754618    5.151849
# min    -54.800000 -175.200000   28.400000    1.000000    0.000000    0.400000
# 25%     -4.450000  -62.815000   57.200000   58.000000    8.000000    4.040000
# 50%     28.070000   21.190000   69.010000   75.000000   50.000000    6.930000
# 75%     49.730000  100.515000   78.925000   86.000000   86.500000   10.830000
# max     78.220000  179.320000  102.200000  100.000000  100.000000   28.860000
#
#                Date
# count  5.790000e+02
# mean   1.592437e+09
# std    6.383868e+01
# min    1.592436e+09
# 25%    1.592437e+09
# 50%    1.592437e+09
# 75%    1.592437e+09
# max    1.592437e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Show the cities that have humidity over 100%.
city_data.loc[city_data['Humidity']>100]
# Out:
# Empty DataFrame
# Columns: [City, Lat, Long, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.
city_index = [i for i in range(len(city_data['Humidity'])) if city_data['Humidity'][i]>100]
city_index
# Out:
# []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = city_data.drop(index=city_index,inplace=False)
clean_city_data.columns.name = 'City_ID'
clean_city_data.head()
# Out:
# City_ID            City    Lat    Long  Max Temp  Humidity  Cloudiness  \
# 0        Cabo San Lucas  22.89 -109.91     93.20        16          20
# 1             Mahébourg -20.41   57.70     69.80        88          75
# 2          Punta Arenas -53.15  -70.92     28.40        92           0
# 3                 Airai  -8.93  125.41     58.91       100          56
# 4         Mar del Plata -38.00  -57.56     60.80       100          90
#
# City_ID  Wind Speed Country        Date
# 0             11.41      MX  1592436338
# 1             18.34      MU  1592436584
# 2              4.05      CL  1592436498
# 3              5.35      TL  1592436585
# 4              3.36      AR  1592436585

# %%
# Export the City_Data into a csv
clean_city_data.to_csv(output_data_file, index_label = 'City_ID')

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build a scatter plot for Latitude vs. Temperature w/ Labels
plt.scatter(clean_city_data["Lat"], clean_city_data["Max Temp"])
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1 Latitude vs Temperature.png")

# Show plot
plt.show()

# %% [markdown]
# #### This plot is showing that as you get closer to the equator (Latitude = 0), the Max Temperature in those cities tends to be higher.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build a scatter plot for Latitude vs. Humidity w/ Labels
plt.scatter(clean_city_data["Lat"], clean_city_data["Humidity"])
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2 Latitude vs Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### This plot is showing that humidity tends to increase as the city is further away from the equator.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for Latitude vs. Cloudiness w/ Labels
plt.scatter(clean_city_data["Lat"], clean_city_data["Cloudiness"])
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3 Latitude vs Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### This plot is showing that a cities cloudiness is not really dependent on how far away from the equator it is.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for Latitude vs. Wind Speed w/ Labels
plt.scatter(clean_city_data["Lat"], clean_city_data["Wind Speed"])
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4 Latitude vs Wind Speed.png")

# Show plot
plt.show()

# %% [markdown]
# #### This plot is showing that a cities wind speed is not really dependent on how far away from the equator it is.

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
clean_city_data.rename(columns = {'Lat':'Latitude'}, inplace = True)
northern_hemisphere = clean_city_data.loc[clean_city_data['Latitude']>=0]
southern_hemisphere = clean_city_data.loc[clean_city_data['Latitude']<0]

#Create list of latitudes
nh_latitude = northern_hemisphere['Latitude']
sh_latitude = southern_hemisphere['Latitude']

# %%
# OPTIONAL: Create a function to create Linear Regression plots
# Store wanted variables in new list
nh_variables = [northern_hemisphere['Max Temp'],northern_hemisphere['Humidity'],
                northern_hemisphere['Cloudiness'],northern_hemisphere['Wind Speed']]
sh_variables = [southern_hemisphere['Max Temp'],southern_hemisphere['Humidity'],
                southern_hemisphere['Cloudiness'],southern_hemisphere['Wind Speed']]

# %%
#Form empty lists to store regression values
slope_results = []
intercept_results = []
rvalue_results = []
regress_values = []
line_eq = []
r_squared = []

#Run for loop to get all regression values for Northern Hemisphere
for variable in range(len(nh_variables)):
    [slope, intercept, rvalue, pvalue, stderr] = linregress(nh_latitude, nh_variables[variable])
    slope_results.append(slope)
    intercept_results.append(intercept)
    rvalue_results.append(rvalue)
    regress_values.append(nh_latitude * slope_results[variable]+intercept_results[variable])
    line_eq.append("y = " + str(round(slope,2)) + "x + " + str(round(intercept,2)))
    r_squared.append("R^2 = " + str(round(rvalue**2,3)))

#Run for loop to get all regression values for Southern Hemisphere
for variable in range(len(sh_variables)):
    [slope1, intercept1, rvalue1, pvalue1, stderr1] = linregress(sh_latitude, sh_variables[variable])
    slope_results.append(slope1)
    intercept_results.append(intercept1)
    rvalue_results.append(rvalue1)
    regress_values.append(sh_latitude * slope_results[variable+len(nh_variables)]+intercept_results[variable+len(nh_variables)])
    line_eq.append("y = " + str(round(slope1,2)) + "x + " + str(round(intercept1,2)))
    r_squared.append("R^2 = " + str(round(rvalue1**2,3)))

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Display and save plot w/ linear regression
northern_hemisphere.plot.scatter('Latitude', 'Max Temp', title = "Northern Hemisphere City Latitude vs. Max Temp")
plt.plot(nh_latitude,regress_values[0], color = 'r')
plt.annotate(line_eq[0],(3,60), fontsize=12, color = 'r')
plt.annotate(r_squared[0],(5,55), fontsize=12, color = 'r')
plt.savefig("output_data/Fig5 Northern Hemisphere City Latitude vs. Max Temp.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Display and save plot w/ linear regression
southern_hemisphere.plot.scatter('Latitude', 'Max Temp', title = "Southern Hemisphere City Latitude vs. Max Temp")
plt.plot(sh_latitude,regress_values[4], color = 'r')
plt.annotate(line_eq[4],(-52,70), fontsize=12, color = 'r')
plt.annotate(r_squared[4],(-50,65), fontsize=12, color = 'r')
plt.savefig("output_data/Fig6 Southern Hemisphere City Latitude vs. Max Temp.png")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Display and save plot w/ linear regression
northern_hemisphere.plot.scatter('Latitude', 'Humidity', title = "Northern Hemisphere City Latitude vs. Humidity")
plt.plot(nh_latitude,regress_values[1], color = 'r')
plt.annotate(line_eq[1],(0,37), fontsize=12, color = 'r')
plt.annotate(r_squared[1],(3,30), fontsize=12, color = 'r')
plt.savefig("output_data/Fig7 Northern Hemisphere City Latitude vs. Humidity.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Display and save plot w/ linear regression
southern_hemisphere.plot.scatter('Latitude', 'Humidity', title = "Southern Hemisphere City Latitude vs. Humidity")
plt.plot(sh_latitude,regress_values[5], color = 'r')
plt.annotate(line_eq[5],(-55,60), fontsize=12, color = 'r')
plt.annotate(r_squared[5],(-53,52), fontsize=12, color = 'r')
plt.savefig("output_data/Fig8 Southern Hemisphere City Latitude vs. Humidity.png")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Display and save plot w/ linear regression
northern_hemisphere.plot.scatter('Latitude', 'Cloudiness', title = "Northern Hemisphere City Latitude vs. Cloudiness")
plt.plot(nh_latitude,regress_values[2], color = 'r')
plt.annotate(line_eq[2],(10,67), fontsize=12, color = 'r')
plt.annotate(r_squared[2],(15,60), fontsize=12, color = 'r')
plt.savefig("output_data/Fig9 Northern Hemisphere City Latitude vs. Cloudiness.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Display and save plot w/ linear regression
southern_hemisphere.plot.scatter('Latitude', 'Cloudiness', title = "Southern Hemisphere City Latitude vs. Cloudiness")
plt.plot(sh_latitude,regress_values[6], color = 'r')
plt.annotate(line_eq[6],(-40,56), fontsize=12, color = 'r')
plt.annotate(r_squared[6],(-35,48), fontsize=12, color = 'r')
plt.savefig("output_data/Fig10 Southern Hemisphere City Latitude vs. Cloudiness.png")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Display and save plot w/ linear regression
northern_hemisphere.plot.scatter('Latitude', 'Wind Speed', title = "Northern Hemisphere City Latitude vs. Wind Speed")
plt.plot(nh_latitude,regress_values[3], color = 'r')
plt.annotate(line_eq[3],(45,25), fontsize=12, color = 'r')
plt.annotate(r_squared[3],(50,22), fontsize=12, color = 'r')
plt.savefig("output_data/Fig11 Northern Hemisphere City Latitude vs. Wind Speed.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Display and save plot w/ linear regression
southern_hemisphere.plot.scatter('Latitude', 'Wind Speed', title = "Southern Hemisphere City Latitude vs. Wind Speed")
plt.plot(sh_latitude,regress_values[7], color = 'r')
plt.annotate(line_eq[7],(-55,18), fontsize=12, color = 'r')
plt.annotate(r_squared[7],(-53,16), fontsize=12, color = 'r')
plt.savefig("output_data/Fig12 Southern Hemisphere City Latitude vs. Wind Speed.png")
plt.show()
