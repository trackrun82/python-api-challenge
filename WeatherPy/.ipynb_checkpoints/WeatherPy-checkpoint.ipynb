# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 615

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

#Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

#set up lists to hold weather response info
city_name = []
lat = []
long = []
maxtemp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

#Being print statement
print ("Beginning Data Retrieval")
print ("-------------------------")

#Loop through list of cities and perform request for weather data on each
for city in cities:
    response = requests.get(query_url + city).json()
    try:
        lat.append(response['coord']['lat'])
        long.append(response['coord']['lon'])
        maxtemp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        city_number = len(cloudiness)
        print (f'Processing Record {city_number}:{city}')
        city_name.append(response['name'])
    
    #If city search cannot retrieve temperature data, print statement
    except:
        print ("City not found...skipping")

#End print statement
print ("-------------------------")
print ("Data Retrieval Complete")
print ("-------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1:sitka
# Processing Record 2:rikitea
# Processing Record 3:torbay
# Processing Record 4:mujiayingzi
# Processing Record 5:albany
# Processing Record 6:homa bay
# Processing Record 7:teguise
# Processing Record 8:high level
# Processing Record 9:svetlogorsk
# Processing Record 10:hermanus
# Processing Record 11:san pedro ayampuc
# Processing Record 12:ushuaia
# Processing Record 13:busselton
# City not found...skipping
# Processing Record 14:yokadouma
# Processing Record 15:upernavik
# Processing Record 16:saint george
# Processing Record 17:avarua
# Processing Record 18:thompson
# Processing Record 19:kruisfontein
# Processing Record 20:ginda
# Processing Record 21:jamestown
# Processing Record 22:bredasdorp
# Processing Record 23:lambari
# Processing Record 24:kahului
# Processing Record 25:bluff
# Processing Record 26:new norfolk
# Processing Record 27:sterling
# Processing Record 28:khatanga
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data = pd.DataFrame({"City": city_name, "Lat": lat, "Long": long,
                             "Max Temp": maxtemp, "Humidity": humidity, "Cloudiness": cloudiness,
                             "Wind Speed": wind_speed, "Country": country, "Date": date})

# %%
city_data.describe()
# Out:
#               Lat        Long    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  555.000000  555.000000  555.000000  555.000000  555.000000  555.000000
# mean    19.762288   16.026721   67.724541   68.661261   46.990991    8.320036
# std     33.251246   89.798047   13.876833   22.155356   37.412979    5.667696
# min    -54.800000 -175.200000   30.200000    3.000000    0.000000    0.380000
# 25%     -8.130000  -62.825000   58.090000   55.000000    8.000000    3.850000
# 50%     24.410000   20.070000   68.790000   74.000000   40.000000    6.930000
# 75%     47.660000   92.410000   78.470000   86.000000   85.500000   11.410000
# max     78.220000  179.320000  100.270000  100.000000  100.000000   32.210000
#
#                Date
# count  5.550000e+02
# mean   1.592348e+09
# std    7.275653e+01
# min    1.592348e+09
# 25%    1.592348e+09
# 50%    1.592348e+09
# 75%    1.592348e+09
# max    1.592348e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Show the cities that have humidity over 100%.
city_data.loc[city_data['Humidity']>100]
# Out:
# Empty DataFrame
# Columns: [City, Lat, Long, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.
city_index = [i for i in range(len(city_data['Humidity'])) if city_data['Humidity'][i]>100]
city_index
# Out:
# []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = city_data.drop(index=city_index,inplace=False)
clean_city_data.columns.name = 'City_ID'
clean_city_data.head()
# Out:
# City_ID         City    Lat    Long  Max Temp  Humidity  Cloudiness  \
# 0              Sitka  57.05 -135.33     51.80        81          75
# 1            Rikitea -23.12 -134.97     75.54        78          72
# 2             Torbay  47.67  -52.73     64.40        45          75
# 3        Mujiayingzi  42.12  118.78     77.11        27          64
# 4             Albany  42.60  -73.97     82.00        35           0
#
# City_ID  Wind Speed Country        Date
# 0              9.17      US  1592348338
# 1             12.66      PF  1592348338
# 2             17.22      CA  1592348339
# 3              8.97      CN  1592348215
# 4              0.76      US  1592348136

# %%
# Export the City_Data into a csv
clean_city_data.to_csv(output_data_file, index_label = 'City_ID')

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build a scatter plot for Latitude vs. Temperature w/ Labels
plt.scatter(clean_city_data["Lat"], clean_city_data["Max Temp"])
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1 Latitude vs Temperature.png")

# Show plot
plt.show()

# %% [markdown]
# #### This plot is showing that as you get closer to the equator (Latitude = 0), the Max Temperature in those cities tends to be higher.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build a scatter plot for Latitude vs. Humidity w/ Labels
plt.scatter(clean_city_data["Lat"], clean_city_data["Humidity"])
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2 Latitude vs Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### This plot is showing that humidity tends to increase as the city is further away from the equator.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for Latitude vs. Cloudiness w/ Labels
plt.scatter(clean_city_data["Lat"], clean_city_data["Cloudiness"])
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3 Latitude vs Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### This plot is showing that a cities cloudiness is not really dependent on how far away from the equator it is.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for Latitude vs. Wind Speed w/ Labels
plt.scatter(clean_city_data["Lat"], clean_city_data["Wind Speed"])
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4 Latitude vs Wind Speed.png")

# Show plot
plt.show()

# %% [markdown]
# #### This plot is showing that a cities wind speed is not really dependent on how far away from the equator it is.

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
clean_city_data.rename(columns = {'Lat':'Latitude'}, inplace = True)
northern_hemisphere = clean_city_data.loc[clean_city_data['Latitude']>=0]
southern_hemisphere = clean_city_data.loc[clean_city_data['Latitude']<0]

#Create list of latitudes
nh_latitude = northern_hemisphere['Latitude']
sh_latitude = southern_hemisphere['Latitude']
slope = []

# %%
# OPTIONAL: Create a function to create Linear Regression plots
# Store wanted variables in new list
nh_variables = [northern_hemisphere['Max Temp'],northern_hemisphere['Humidity'],
                northern_hemisphere['Cloudiness'],northern_hemisphere['Wind Speed']]
sh_variables = [southern_hemisphere['Max Temp'],southern_hemisphere['Humidity'],
                southern_hemisphere['Cloudiness'],southern_hemisphere['Wind Speed']]

# %%
#Run linear regression for Northern Hemisphere
for variable in range(len(nh_variables)):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(nh_latitude, nh_variables[variable])
    print(slope, intercept, rvalue)
    
#     regress_values = nh_latitude * slope[variable] + intercept[variable]
#     print({regress_values})
# line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# r_squared = "R^2 = " + str(round(rvalue**2,3))
# Out:
# -0.49190599870321766 87.90893843769824 -0.6962039973274907
# -0.14671952350724557 71.16859165929098 -0.12824895286629817
# -0.18829643173506677 56.87417831159786 -0.10044159388322281
# 0.014532375611971921 7.9083096648553495 0.05062858182613814

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Run linear regression on Temp vs Latitude for Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(nh_latitude, nh_variables[0])
regress_values = nh_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_squared = "R^2 = " + str(round(rvalue**2,3))

#Display and save plot w/ linear regression
northern_hemisphere.plot.scatter('Latitude', 'Max Temp', title = "Northern Hemisphere City Latitude vs. Max Temp")
plt.plot(nh_latitude,regress_values, color = 'r')
plt.annotate(line_eq,(3,60), fontsize=12, color = 'r')
plt.annotate(r_squared,(5,55), fontsize=12, color = 'r')
plt.savefig("output_data/Fig5 Northern Hemisphere City Latitude vs. Max Temp.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Run linear regression on Temp vs Latitude for Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(sh_latitude, southern_hemisphere['Max Temp'])
regress_values = sh_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_squared = "R^2 = " + str(round(rvalue**2,3))

#Display and save plot w/ linear regression
southern_hemisphere.plot.scatter('Latitude', 'Max Temp', title = "Southern Hemisphere City Latitude vs. Max Temp")
plt.plot(sh_latitude,regress_values, color = 'r')
plt.annotate(line_eq,(-52,70), fontsize=12, color = 'r')
plt.annotate(r_squared,(-50,65), fontsize=12, color = 'r')
plt.savefig("output_data/Fig6 Southern Hemisphere City Latitude vs. Max Temp.png")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Run linear regression on Humidity vs Latitude for Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(nh_latitude, northern_hemisphere['Humidity'])
regress_values = nh_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_squared = "R^2 = " + str(round(rvalue**2,3))

#Display and save plot w/ linear regression
northern_hemisphere.plot.scatter('Latitude', 'Humidity', title = "Northern Hemisphere City Latitude vs. Humidity")
plt.plot(nh_latitude,regress_values, color = 'r')
plt.annotate(line_eq,(0,37), fontsize=12, color = 'r')
plt.annotate(r_squared,(3,30), fontsize=12, color = 'r')
plt.savefig("output_data/Fig7 Northern Hemisphere City Latitude vs. Humidity.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Run linear regression on Humidity vs Latitude for Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(sh_latitude, southern_hemisphere['Humidity'])
regress_values = sh_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_squared = "R^2 = " + str(round(rvalue**2,3))

#Display and save plot w/ linear regression
southern_hemisphere.plot.scatter('Latitude', 'Humidity', title = "Southern Hemisphere City Latitude vs. Humidity")
plt.plot(sh_latitude,regress_values, color = 'r')
plt.annotate(line_eq,(-55,60), fontsize=12, color = 'r')
plt.annotate(r_squared,(-53,52), fontsize=12, color = 'r')
plt.savefig("output_data/Fig8 Southern Hemisphere City Latitude vs. Humidity.png")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Run linear regression on Cloudiness vs Latitude for Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(nh_latitude, northern_hemisphere['Cloudiness'])
regress_values = nh_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_squared = "R^2 = " + str(round(rvalue**2,3))

#Display and save plot w/ linear regression
northern_hemisphere.plot.scatter('Latitude', 'Cloudiness', title = "Northern Hemisphere City Latitude vs. Cloudiness")
plt.plot(nh_latitude,regress_values, color = 'r')
plt.annotate(line_eq,(10,65), fontsize=12, color = 'r')
plt.annotate(r_squared,(15,58), fontsize=12, color = 'r')
plt.savefig("output_data/Fig9 Northern Hemisphere City Latitude vs. Cloudiness.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Run linear regression on Cloudiness vs Latitude for Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(sh_latitude, southern_hemisphere['Cloudiness'])
regress_values = sh_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_squared = "R^2 = " + str(round(rvalue**2,3))

#Display and save plot w/ linear regression
southern_hemisphere.plot.scatter('Latitude', 'Cloudiness', title = "Southern Hemisphere City Latitude vs. Cloudiness")
plt.plot(sh_latitude,regress_values, color = 'r')
plt.annotate(line_eq,(-40,56), fontsize=12, color = 'r')
plt.annotate(r_squared,(-35,48), fontsize=12, color = 'r')
plt.savefig("output_data/Fig10 Southern Hemisphere City Latitude vs. Cloudiness.png")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Run linear regression on Wind Speed vs Latitude for Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(nh_latitude, northern_hemisphere['Wind Speed'])
regress_values = nh_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_squared = "R^2 = " + str(round(rvalue**2,3))

#Display and save plot w/ linear regression
northern_hemisphere.plot.scatter('Latitude', 'Wind Speed', title = "Northern Hemisphere City Latitude vs. Wind Speed")
plt.plot(nh_latitude,regress_values, color = 'r')
plt.annotate(line_eq,(45,25), fontsize=12, color = 'r')
plt.annotate(r_squared,(50,22), fontsize=12, color = 'r')
plt.savefig("output_data/Fig11 Northern Hemisphere City Latitude vs. Wind Speed.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Run linear regression on Wind Speed vs Latitude for Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(sh_latitude, southern_hemisphere['Wind Speed'])
regress_values = sh_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_squared = "R^2 = " + str(round(rvalue**2,3))

#Display and save plot w/ linear regression
southern_hemisphere.plot.scatter('Latitude', 'Wind Speed', title = "Southern Hemisphere City Latitude vs. Wind Speed")
plt.plot(sh_latitude,regress_values, color = 'r')
plt.annotate(line_eq,(-55,18), fontsize=12, color = 'r')
plt.annotate(r_squared,(-53,16), fontsize=12, color = 'r')
plt.savefig("output_data/Fig12 Southern Hemisphere City Latitude vs. Wind Speed.png")
plt.show()
